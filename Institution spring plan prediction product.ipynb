# %%
import time

print("Hi, this is a data product that could predict the spring opening plan of instituitons.")
time.sleep(1)
print("I could predict if your institution would be opened in-person or remain total online.")
time.sleep(1.5)
name=input('''To start with, what's the name of your institution?
''')
time.sleep(1)
print("Great, let's start the prediction!")


    
def predict_fall_plan_online(type_public=None,
                             type_4yrs=None,
                             enrollment_10k_=None,
                             know_cases_in__county_1000_=None,
                             tuition_and_fees_2019_20_12k_=None,
                             political_affiliation_rep=None,
                             urbanization_downtown=None,
                             institutional_category_bachelor=None,
                             full_time=None):
    """ Predictor for Fall_plan - online from model/5f7043a8ace11f2f270010bc

        Predictive model by BigML - Machine Learning Made Easy
    """
    if (full_time is None):
        return u'0'
    if (full_time == u'1'):
        if (political_affiliation_rep is None):
            return u'0'
        if (political_affiliation_rep == u'1'):
            if (urbanization_downtown is None):
                return u'0'
            if (urbanization_downtown == u'0'):
                if (institutional_category_bachelor is None):
                    return u'0'
                if (institutional_category_bachelor == u'1'):
                    if (type_public is None):
                        return u'0'
                    if (type_public == u'1'):
                        if (tuition_and_fees_2019_20_12k_ is None):
                            return u'0'
                        if (tuition_and_fees_2019_20_12k_ == u'0'):
                            if (enrollment_10k_ is None):
                                return u'0'
                            if (enrollment_10k_ == u'0'):
                                if (know_cases_in__county_1000_ is None):
                                    return u'0'
                                if (know_cases_in__county_1000_ == u'1'):
                                    return u'0'
                                if (know_cases_in__county_1000_ == u'0'):
                                    return u'0'
                            if (enrollment_10k_ == u'1'):
                                if (know_cases_in__county_1000_ is None):
                                    return u'0'
                                if (know_cases_in__county_1000_ == u'1'):
                                    return u'0'
                                if (know_cases_in__county_1000_ == u'0'):
                                    return u'0'
                        if (tuition_and_fees_2019_20_12k_ == u'1'):
                            if (know_cases_in__county_1000_ is None):
                                return u'0'
                            if (know_cases_in__county_1000_ == u'1'):
                                return u'1'
                            if (know_cases_in__county_1000_ == u'0'):
                                return u'0'
                    if (type_public == u'0'):
                        if (enrollment_10k_ is None):
                            return u'0'
                        if (enrollment_10k_ == u'0'):
                            if (know_cases_in__county_1000_ is None):
                                return u'0'
                            if (know_cases_in__county_1000_ == u'1'):
                                if (tuition_and_fees_2019_20_12k_ is None):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'0'):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'1'):
                                    return u'0'
                            if (know_cases_in__county_1000_ == u'0'):
                                if (tuition_and_fees_2019_20_12k_ is None):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'0'):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'1'):
                                    return u'0'
                        if (enrollment_10k_ == u'1'):
                            if (know_cases_in__county_1000_ is None):
                                return u'0'
                            if (know_cases_in__county_1000_ == u'1'):
                                if (tuition_and_fees_2019_20_12k_ is None):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'0'):
                                    return u'1'
                                if (tuition_and_fees_2019_20_12k_ == u'1'):
                                    return u'0'
                            if (know_cases_in__county_1000_ == u'0'):
                                if (tuition_and_fees_2019_20_12k_ is None):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'0'):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'1'):
                                    return u'1'
                if (institutional_category_bachelor == u'0'):
                    if (know_cases_in__county_1000_ is None):
                        return u'0'
                    if (know_cases_in__county_1000_ == u'1'):
                        if (type_public is None):
                            return u'1'
                        if (type_public == u'1'):
                            if (enrollment_10k_ is None):
                                return u'1'
                            if (enrollment_10k_ == u'0'):
                                if (type_4yrs is None):
                                    return u'1'
                                if (type_4yrs == u'1'):
                                    return u'1'
                                if (type_4yrs == u'0'):
                                    return u'1'
                            if (enrollment_10k_ == u'1'):
                                return u'0'
                        if (type_public == u'0'):
                            if (enrollment_10k_ is None):
                                return u'0'
                            if (enrollment_10k_ == u'0'):
                                return u'0'
                            if (enrollment_10k_ == u'1'):
                                return u'1'
                    if (know_cases_in__county_1000_ == u'0'):
                        if (tuition_and_fees_2019_20_12k_ is None):
                            return u'0'
                        if (tuition_and_fees_2019_20_12k_ == u'0'):
                            if (type_4yrs is None):
                                return u'0'
                            if (type_4yrs == u'1'):
                                if (type_public is None):
                                    return u'0'
                                if (type_public == u'1'):
                                    return u'0'
                                if (type_public == u'0'):
                                    return u'1'
                            if (type_4yrs == u'0'):
                                if (type_public is None):
                                    return u'0'
                                if (type_public == u'1'):
                                    return u'0'
                                if (type_public == u'0'):
                                    return u'0'
                        if (tuition_and_fees_2019_20_12k_ == u'1'):
                            return u'0'
            if (urbanization_downtown == u'1'):
                if (enrollment_10k_ is None):
                    return u'0'
                if (enrollment_10k_ == u'0'):
                    if (institutional_category_bachelor is None):
                        return u'0'
                    if (institutional_category_bachelor == u'1'):
                        if (tuition_and_fees_2019_20_12k_ is None):
                            return u'0'
                        if (tuition_and_fees_2019_20_12k_ == u'0'):
                            if (type_public is None):
                                return u'0'
                            if (type_public == u'1'):
                                if (know_cases_in__county_1000_ is None):
                                    return u'0'
                                if (know_cases_in__county_1000_ == u'1'):
                                    return u'0'
                                if (know_cases_in__county_1000_ == u'0'):
                                    return u'0'
                            if (type_public == u'0'):
                                return u'1'
                        if (tuition_and_fees_2019_20_12k_ == u'1'):
                            if (know_cases_in__county_1000_ is None):
                                return u'0'
                            if (know_cases_in__county_1000_ == u'1'):
                                return u'0'
                            if (know_cases_in__county_1000_ == u'0'):
                                return u'0'
                    if (institutional_category_bachelor == u'0'):
                        if (type_public is None):
                            return u'0'
                        if (type_public == u'1'):
                            if (type_4yrs is None):
                                return u'0'
                            if (type_4yrs == u'1'):
                                return u'0'
                            if (type_4yrs == u'0'):
                                return u'0'
                        if (type_public == u'0'):
                            return u'1'
                if (enrollment_10k_ == u'1'):
                    if (institutional_category_bachelor is None):
                        return u'0'
                    if (institutional_category_bachelor == u'1'):
                        if (tuition_and_fees_2019_20_12k_ is None):
                            return u'0'
                        if (tuition_and_fees_2019_20_12k_ == u'0'):
                            if (know_cases_in__county_1000_ is None):
                                return u'0'
                            if (know_cases_in__county_1000_ == u'1'):
                                return u'0'
                            if (know_cases_in__county_1000_ == u'0'):
                                return u'0'
                        if (tuition_and_fees_2019_20_12k_ == u'1'):
                            if (type_public is None):
                                return u'1'
                            if (type_public == u'1'):
                                return u'1'
                            if (type_public == u'0'):
                                return u'0'
                    if (institutional_category_bachelor == u'0'):
                        return u'0'
        if (political_affiliation_rep != u'1'):
            if (tuition_and_fees_2019_20_12k_ is None):
                return u'1'
            if (tuition_and_fees_2019_20_12k_ == u'0'):
                if (know_cases_in__county_1000_ is None):
                    return u'1'
                if (know_cases_in__county_1000_ == u'1'):
                    if (institutional_category_bachelor is None):
                        return u'1'
                    if (institutional_category_bachelor == u'1'):
                        if (enrollment_10k_ is None):
                            return u'1'
                        if (enrollment_10k_ == u'0'):
                            if (urbanization_downtown is None):
                                return u'1'
                            if (urbanization_downtown == u'0'):
                                return u'1'
                            if (urbanization_downtown == u'1'):
                                if (type_public is None):
                                    return u'1'
                                if (type_public == u'1'):
                                    return u'1'
                                if (type_public == u'0'):
                                    return u'0'
                        if (enrollment_10k_ == u'1'):
                            if (urbanization_downtown is None):
                                return u'1'
                            if (urbanization_downtown == u'0'):
                                return u'1'
                            if (urbanization_downtown == u'1'):
                                return u'1'
                    if (institutional_category_bachelor == u'0'):
                        if (enrollment_10k_ is None):
                            return u'1'
                        if (enrollment_10k_ == u'0'):
                            if (type_public is None):
                                return u'1'
                            if (type_public == u'1'):
                                if (urbanization_downtown is None):
                                    return u'1'
                                if (urbanization_downtown == u'0'):
                                    if (type_4yrs is None):
                                        return u'1'
                                    if (type_4yrs == u'1'):
                                        return u'1'
                                    if (type_4yrs == u'0'):
                                        return u'1'
                                if (urbanization_downtown == u'1'):
                                    if (type_4yrs is None):
                                        return u'1'
                                    if (type_4yrs == u'1'):
                                        return u'1'
                                    if (type_4yrs == u'0'):
                                        return u'1'
                            if (type_public == u'0'):
                                if (urbanization_downtown is None):
                                    return u'0'
                                if (urbanization_downtown == u'0'):
                                    return u'1'
                                if (urbanization_downtown == u'1'):
                                    return u'0'
                        if (enrollment_10k_ == u'1'):
                            return u'1'
                if (know_cases_in__county_1000_ == u'0'):
                    if (enrollment_10k_ is None):
                        return u'1'
                    if (enrollment_10k_ == u'0'):
                        if (type_public is None):
                            return u'1'
                        if (type_public == u'1'):
                            if (urbanization_downtown is None):
                                return u'1'
                            if (urbanization_downtown == u'0'):
                                if (institutional_category_bachelor is None):
                                    return u'1'
                                if (institutional_category_bachelor == u'1'):
                                    return u'1'
                                if (institutional_category_bachelor == u'0'):
                                    if (type_4yrs is None):
                                        return u'1'
                                    if (type_4yrs == u'1'):
                                        return u'0'
                                    if (type_4yrs == u'0'):
                                        return u'1'
                            if (urbanization_downtown == u'1'):
                                if (type_4yrs is None):
                                    return u'0'
                                if (type_4yrs == u'1'):
                                    return u'0'
                                if (type_4yrs == u'0'):
                                    return u'1'
                        if (type_public == u'0'):
                            return u'0'
                    if (enrollment_10k_ == u'1'):
                        return u'1'
            if (tuition_and_fees_2019_20_12k_ == u'1'):
                if (know_cases_in__county_1000_ is None):
                    return u'0'
                if (know_cases_in__county_1000_ == u'1'):
                    if (political_affiliation_rep == u'0'):
                        if (type_4yrs is None):
                            return u'0'
                        if (type_4yrs == u'1'):
                            if (institutional_category_bachelor is None):
                                return u'0'
                            if (institutional_category_bachelor == u'1'):
                                if (type_public is None):
                                    return u'0'
                                if (type_public == u'1'):
                                    if (urbanization_downtown is None):
                                        return u'1'
                                    if (urbanization_downtown == u'0'):
                                        if (enrollment_10k_ is None):
                                            return u'0'
                                        if (enrollment_10k_ == u'0'):
                                            return u'0'
                                        if (enrollment_10k_ == u'1'):
                                            return u'1'
                                    if (urbanization_downtown == u'1'):
                                        return u'1'
                                if (type_public == u'0'):
                                    if (urbanization_downtown is None):
                                        return u'0'
                                    if (urbanization_downtown == u'0'):
                                        if (enrollment_10k_ is None):
                                            return u'0'
                                        if (enrollment_10k_ == u'0'):
                                            return u'1'
                                        if (enrollment_10k_ == u'1'):
                                            return u'0'
                                    if (urbanization_downtown == u'1'):
                                        if (enrollment_10k_ is None):
                                            return u'0'
                                        if (enrollment_10k_ == u'0'):
                                            return u'0'
                                        if (enrollment_10k_ == u'1'):
                                            return u'1'
                            if (institutional_category_bachelor == u'0'):
                                return u'0'
                        if (type_4yrs == u'0'):
                            return u'1'
                    if (political_affiliation_rep != u'0'):
                        return u'1'
                if (know_cases_in__county_1000_ == u'0'):
                    if (institutional_category_bachelor is None):
                        return u'0'
                    if (institutional_category_bachelor == u'1'):
                        if (enrollment_10k_ is None):
                            return u'0'
                        if (enrollment_10k_ == u'0'):
                            if (type_public is None):
                                return u'0'
                            if (type_public == u'1'):
                                return u'0'
                            if (type_public == u'0'):
                                if (urbanization_downtown is None):
                                    return u'0'
                                if (urbanization_downtown == u'0'):
                                    return u'0'
                                if (urbanization_downtown == u'1'):
                                    return u'0'
                        if (enrollment_10k_ == u'1'):
                            return u'0'
                    if (institutional_category_bachelor == u'0'):
                        return u'0'
    if (full_time == u'0'):
        if (enrollment_10k_ is None):
            return u'1'
        if (enrollment_10k_ == u'0'):
            if (political_affiliation_rep is None):
                return u'1'
            if (political_affiliation_rep == u'1'):
                if (urbanization_downtown is None):
                    return u'1'
                if (urbanization_downtown == u'0'):
                    if (tuition_and_fees_2019_20_12k_ is None):
                        return u'1'
                    if (tuition_and_fees_2019_20_12k_ == u'0'):
                        if (know_cases_in__county_1000_ is None):
                            return u'1'
                        if (know_cases_in__county_1000_ == u'1'):
                            if (type_4yrs is None):
                                return u'0'
                            if (type_4yrs == u'1'):
                                return u'0'
                            if (type_4yrs == u'0'):
                                return u'1'
                        if (know_cases_in__county_1000_ == u'0'):
                            if (type_4yrs is None):
                                return u'1'
                            if (type_4yrs == u'1'):
                                return u'1'
                            if (type_4yrs == u'0'):
                                return u'1'
                    if (tuition_and_fees_2019_20_12k_ == u'1'):
                        return u'0'
                if (urbanization_downtown == u'1'):
                    if (tuition_and_fees_2019_20_12k_ is None):
                        return u'1'
                    if (tuition_and_fees_2019_20_12k_ == u'0'):
                        if (type_public is None):
                            return u'1'
                        if (type_public == u'1'):
                            if (institutional_category_bachelor is None):
                                return u'1'
                            if (institutional_category_bachelor == u'1'):
                                return u'1'
                            if (institutional_category_bachelor == u'0'):
                                if (type_4yrs is None):
                                    return u'1'
                                if (type_4yrs == u'1'):
                                    return u'0'
                                if (type_4yrs == u'0'):
                                    return u'1'
                        if (type_public == u'0'):
                            return u'0'
                    if (tuition_and_fees_2019_20_12k_ == u'1'):
                        if (institutional_category_bachelor is None):
                            return u'1'
                        if (institutional_category_bachelor == u'1'):
                            return u'1'
                        if (institutional_category_bachelor == u'0'):
                            return u'1'
            if (political_affiliation_rep != u'1'):
                if (know_cases_in__county_1000_ is None):
                    return u'1'
                if (know_cases_in__county_1000_ == u'1'):
                    if (institutional_category_bachelor is None):
                        return u'1'
                    if (institutional_category_bachelor == u'1'):
                        if (urbanization_downtown is None):
                            return u'1'
                        if (urbanization_downtown == u'0'):
                            return u'1'
                        if (urbanization_downtown == u'1'):
                            if (tuition_and_fees_2019_20_12k_ is None):
                                return u'1'
                            if (tuition_and_fees_2019_20_12k_ == u'0'):
                                return u'1'
                            if (tuition_and_fees_2019_20_12k_ == u'1'):
                                return u'0'
                    if (institutional_category_bachelor == u'0'):
                        if (type_public is None):
                            return u'1'
                        if (type_public == u'1'):
                            if (urbanization_downtown is None):
                                return u'1'
                            if (urbanization_downtown == u'0'):
                                if (type_4yrs is None):
                                    return u'1'
                                if (type_4yrs == u'1'):
                                    return u'1'
                                if (type_4yrs == u'0'):
                                    return u'1'
                            if (urbanization_downtown == u'1'):
                                if (type_4yrs is None):
                                    return u'1'
                                if (type_4yrs == u'1'):
                                    return u'1'
                                if (type_4yrs == u'0'):
                                    return u'1'
                        if (type_public == u'0'):
                            return u'1'
                if (know_cases_in__county_1000_ == u'0'):
                    if (type_public is None):
                        return u'1'
                    if (type_public == u'1'):
                        if (institutional_category_bachelor is None):
                            return u'1'
                        if (institutional_category_bachelor == u'1'):
                            return u'1'
                        if (institutional_category_bachelor == u'0'):
                            if (type_4yrs is None):
                                return u'1'
                            if (type_4yrs == u'1'):
                                return u'1'
                            if (type_4yrs == u'0'):
                                if (urbanization_downtown is None):
                                    return u'1'
                                if (urbanization_downtown == u'0'):
                                    return u'1'
                                if (urbanization_downtown == u'1'):
                                    return u'0'
                    if (type_public == u'0'):
                        return u'0'
        if (enrollment_10k_ == u'1'):
            if (type_4yrs is None):
                return u'1'
            if (type_4yrs == u'1'):
                if (type_public is None):
                    return u'1'
                if (type_public == u'1'):
                    if (know_cases_in__county_1000_ is None):
                        return u'1'
                    if (know_cases_in__county_1000_ == u'1'):
                        if (political_affiliation_rep is None):
                            return u'1'
                        if (political_affiliation_rep == u'1'):
                            if (urbanization_downtown is None):
                                return u'1'
                            if (urbanization_downtown == u'0'):
                                if (tuition_and_fees_2019_20_12k_ is None):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'0'):
                                    return u'0'
                                if (tuition_and_fees_2019_20_12k_ == u'1'):
                                    return u'1'
                            if (urbanization_downtown == u'1'):
                                return u'1'
                        if (political_affiliation_rep != u'1'):
                            if (institutional_category_bachelor is None):
                                return u'1'
                            if (institutional_category_bachelor == u'1'):
                                return u'0'
                            if (institutional_category_bachelor == u'0'):
                                return u'1'
                    if (know_cases_in__county_1000_ == u'0'):
                        return u'0'
                if (type_public == u'0'):
                    return u'1'
            if (type_4yrs == u'0'):
                if (political_affiliation_rep is None):
                    return u'1'
                if (political_affiliation_rep == u'1'):
                    if (urbanization_downtown is None):
                        return u'1'
                    if (urbanization_downtown == u'0'):
                        return u'1'
                    if (urbanization_downtown == u'1'):
                        if (know_cases_in__county_1000_ is None):
                            return u'1'
                        if (know_cases_in__county_1000_ == u'1'):
                            return u'1'
                        if (know_cases_in__county_1000_ == u'0'):
                            return u'1'
                if (political_affiliation_rep != u'1'):
                    if (urbanization_downtown is None):
                        return u'1'
                    if (urbanization_downtown == u'0'):
                        return u'1'
                    if (urbanization_downtown == u'1'):
                        return u'1'

                    
type_pub=input('''Is your institution a public one?
Type in Y or N
''')
type_4years=input('''Does your institution provides 4-year program?
Type in Y or N
''')
enrollment=input('''Is your institution's enrollment number higher than 10k?
Type in Y or N
''')
known_cases_in_county=input('''Does the county your institution located have more than 1000 cases recorded?
Type in Y or N
''')
tuition_fees=input('''Is your institution's enrollment fee higher than 12k per year?
Type in Y or N
''')
political_affiliation=input('''Is the political allication of the county your institution located Republic?
Type in Y or N
''')
urbanization=input('''Is your institution located downtown?
Type in Y or N
''')
institutional_category=input('''Does your institution only provide bachelor programs?
Type in Y or N
''')
fulltime=input('''Is your institution a full time?
Type in Y or N
''')
time.sleep(1)

if type_pub=="Y":
    type_public=u'1'
else:
    type_public=u'0'
    
if type_4years=="Y":
    type_4yrs=u'1'
else:
    type_4yrs=u'0'
    
if enrollment=="Y":
    enrollment_10k_=u'1'
else:
    enrollment_10k_=u'0'
    
if known_cases_in_county=="Y":
    know_cases_in__county_1000_=u'1'
else:
    know_cases_in__county_1000_=u'0'
    
if tuition_fees=="Y":
    tuition_and_fees_2019_20_12k_=u'1'
else:
    tuition_and_fees_2019_20_12k_=u'0'
    
if political_affiliation=="Y":
    political_affiliation_rep=u'1'
else:
    political_affiliation_rep=u'0'

if urbanization=="Y":
    urbanization_downtown=u'1'
else:
    urbanization_downtown=u'0'
    
if institutional_category=="Y":
    institutional_category_bachelor=u'1'
else:
    institutional_category_bachelor=u'0'
    
if fulltime=="Y":
    full_time=u'1'
else:
    full_time=u'0'
    

predict=predict_fall_plan_online(type_public,
                         type_4yrs,
                         enrollment_10k_,
                         know_cases_in__county_1000_,
                         tuition_and_fees_2019_20_12k_,
                         political_affiliation_rep, 
                         urbanization_downtown,
                         institutional_category_bachelor,
                         full_time)
if predict=='1':
    print("Got it! In this case, I believe your institution "+name+" will go fully online in spring. Ugh!")
else:
    print("Got it! In this case, I believe your institution "+name+
          " will not go fully online in spring. It might be a hybrid model, or even in-person. Yay!")
# Out:
# Hi, this is a data product that could predict the spring opening plan of instituitons.
# I could predict if your institution would be opened in-person or remain total online.
# To start with, what's the name of your institution?
# Cornell University
# Great, let's start the prediction!
# Is your institution a public one?
# Type in Y or N
# Y
# Does your institution provides 4-year program?
# Type in Y or N
# Y
# Is your institution's enrollment number higher than 10k?
# Type in Y or N
# Y
# Does the county your institution located have more than 1000 cases recorded?
# Type in Y or N
# Y
# Is your institution's enrollment fee higher than 12k per year?
# Type in Y or N
# Y
# Is the political allication of the county your institution located Republic?
# Type in Y or N
# Y
# Is your institution located downtown?
# Type in Y or N
# Y
# Does your institution only provide bachelor programs?
# Type in Y or N
# Y
# Is your institution a full time?
# Type in Y or N
# Y
# ...
